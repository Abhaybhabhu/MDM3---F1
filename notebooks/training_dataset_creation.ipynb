# %%
import pandas as pd
import numpy as np

# %%
# read in file:
physics_data = pd.read_csv("../data/processed/physics_modelled_2022_2025.csv")

# drop unnecessary columns.
drop_col_names = ["BrakeIntensity_raw","BrakeFraction","AccelIntensity_raw","FullThrottleFrac","CorneringSeverity_raw","ThrottleMean_pct","TelemetrySamples","DRSActiveFraction","DRSDetected","BrakeIntensity","AccelIntensity","CorneringSeverity","SlidingProxy"]
physics_data.drop(columns=drop_col_names, inplace=True)
# save the cleaned data as training data.csv
physics_data.to_csv("../data/processed/training_data.csv", index=False)
